# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time



# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
#Google Weather API Key
gkey = 
wkey = 

# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # Replace spaces with %20 to create url correctly 
    city = city.replace(" ", "%20")
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:

        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 649

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + wkey

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
         
        # Increase counter by one 
        record= record + 1
        
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | West Wendover
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=west%20wendover
# Processing Record 2 | Port Hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=port%20hardy
# Processing Record 3 | Mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=mandalgovi
# Processing Record 4 | Chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=chuy
# City not found. Skipping...
# Processing Record 5 | Gunjur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=gunjur
# Processing Record 6 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=norman%20wells
# Processing Record 7 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=clyde%20river
# Processing Record 8 | Matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=matara
# Processing Record 9 | Ravar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=ravar
# Processing Record 10 | San Juan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=san%20juan
# Processing Record 11 | Nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=nantucket
# Processing Record 12 | College
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=college
# Processing Record 13 | Kamenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kamenka
# Processing Record 14 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=rikitea
# Processing Record 15 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=ushuaia
# Processing Record 16 | Ponta Delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=ponta%20delgada
# Processing Record 17 | Sayyan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=sayyan
# Processing Record 18 | Rapid Valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=rapid%20valley
# Processing Record 19 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=bluff
# Processing Record 20 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=pisco
# Processing Record 21 | Den Helder
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=den%20helder
# Processing Record 22 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=mar%20del%20plata
# Processing Record 23 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=punta%20arenas
# City not found. Skipping...
# Processing Record 24 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=port%20alfred
# Processing Record 25 | Surt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=surt
# Processing Record 26 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kapaa
# Processing Record 27 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=saint-philippe
# Processing Record 28 | Koumac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=koumac
# Processing Record 29 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=vila%20franca%20do%20campo
# Processing Record 30 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kavieng
# Processing Record 31 | Caxito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=caxito
# City not found. Skipping...
# Processing Record 32 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=cidreira
# Processing Record 33 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=chokurdakh
# Processing Record 34 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=severo-kurilsk
# Processing Record 35 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=cabo%20san%20lucas
# Processing Record 36 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=klaksvik
# Processing Record 37 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=atuona
# Processing Record 38 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=dikson
# Processing Record 39 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=albany
# Processing Record 40 | Arrifes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=arrifes
# Processing Record 41 | Kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kirakira
# City not found. Skipping...
# Processing Record 42 | Road Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=road%20town
# Processing Record 43 | Axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=axim
# Processing Record 44 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=victoria
# Processing Record 45 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=saskylakh
# Processing Record 46 | Parral
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=parral
# Processing Record 47 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=castro
# Processing Record 48 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=avarua
# Processing Record 49 | Baikunthpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=baikunthpur
# Processing Record 50 | Talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=talnakh
# Processing Record 51 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=yellowknife
# City not found. Skipping...
# Processing Record 52 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=jamestown
# Processing Record 53 | Port Blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=port%20blair
# Processing Record 54 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=hambantota
# Processing Record 55 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=georgetown
# Processing Record 56 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=arraial%20do%20cabo
# Processing Record 57 | Adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=adrar
# Processing Record 58 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=hobart
# City not found. Skipping...
# Processing Record 59 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=katsuura
# Processing Record 60 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=bredasdorp
# Processing Record 61 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=cape%20town
# Processing Record 62 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=vaini
# Processing Record 63 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=coquimbo
# City not found. Skipping...
# Processing Record 64 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=new%20norfolk
# Processing Record 65 | Plettenberg Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=plettenberg%20bay
# Processing Record 66 | Alice Springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=alice%20springs
# Processing Record 67 | Sao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=sao%20joao%20da%20barra
# Processing Record 68 | Emerald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=emerald
# Processing Record 69 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=busselton
# Processing Record 70 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=ostrovnoy
# Processing Record 71 | North Bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=north%20bend
# Processing Record 72 | Severo-Yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=severo-yeniseyskiy
# Processing Record 73 | Luan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=luan
# Processing Record 74 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=mataura
# Processing Record 75 | Bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=bubaque
# Processing Record 76 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=hithadhoo
# Processing Record 77 | Coruripe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=coruripe
# Processing Record 78 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=fortuna
# Processing Record 79 | Buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=buala
# Processing Record 80 | Nabire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=nabire
# Processing Record 81 | Batemans Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=batemans%20bay
# Processing Record 82 | Sept-Iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=sept-iles
# Processing Record 83 | Komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=komsomolskiy
# City not found. Skipping...
# Processing Record 84 | Novaya Ladoga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=novaya%20ladoga
# Processing Record 85 | Westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=westport
# Processing Record 86 | Rangia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=rangia
# Processing Record 87 | Springbok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=springbok
# Processing Record 88 | Zhizdra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=zhizdra
# Processing Record 89 | Nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=nuuk
# Processing Record 90 | Adrasmon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=adrasmon
# Processing Record 91 | Iracoubo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=iracoubo
# Processing Record 92 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kodiak
# Processing Record 93 | Portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=portland
# Processing Record 94 | Bahar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=bahar
# Processing Record 95 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=carnarvon
# Processing Record 96 | Cururupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=cururupu
# Processing Record 97 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=geraldton
# Processing Record 98 | Povenets
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=povenets
# Processing Record 99 | Teluknaga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=teluknaga
# Processing Record 100 | Santiago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=santiago
# Processing Record 101 | Guaymas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=guaymas
# City not found. Skipping...
# Processing Record 102 | Kucevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kucevo
# Processing Record 103 | Batamshinskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=batamshinskiy
# Processing Record 104 | Berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=berlevag
# Processing Record 105 | Auburn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=auburn
# Processing Record 106 | Poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=poum
# Processing Record 107 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=qaanaaq
# City not found. Skipping...
# Processing Record 108 | Rome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=rome
# Processing Record 109 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=nikolskoye
# City not found. Skipping...
# Processing Record 110 | Avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=avera
# Processing Record 111 | Bilibino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=bilibino
# Processing Record 112 | Itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=itarema
# Processing Record 113 | Morant Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=morant%20bay
# Processing Record 114 | Yeniseysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=yeniseysk
# Processing Record 115 | La Reforma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=la%20reforma
# Processing Record 116 | Venice
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=venice
# Processing Record 117 | Mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=mitsamiouli
# Processing Record 118 | Bikaner
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=bikaner
# Processing Record 119 | Kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kununurra
# Processing Record 120 | Amazar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=amazar
# City not found. Skipping...
# Processing Record 121 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=lebu
# Processing Record 122 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=faanui
# Processing Record 123 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=ribeira%20grande
# Processing Record 124 | Beyneu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=beyneu
# Processing Record 125 | Mayor Pablo Lagerenza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=mayor%20pablo%20lagerenza
# Processing Record 126 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=mahebourg
# Processing Record 127 | Erzin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=erzin
# Processing Record 128 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=airai
# Processing Record 129 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=provideniya
# Processing Record 130 | Trofaiach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=trofaiach
# City not found. Skipping...
# Processing Record 131 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=butaritari
# City not found. Skipping...
# Processing Record 132 | Aki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=aki
# Processing Record 133 | Kyshtovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kyshtovka
# Processing Record 134 | Anapskaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=anapskaya
# Processing Record 135 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=hilo
# Processing Record 136 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=tasiilaq
# Processing Record 137 | Atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=atar
# Processing Record 138 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=constitucion
# Processing Record 139 | Padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=padang
# Processing Record 140 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=mount%20gambier
# Processing Record 141 | Warrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=warrington
# Processing Record 142 | Teahupoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=teahupoo
# Processing Record 143 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=thompson
# Processing Record 144 | Tungor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=tungor
# Processing Record 145 | Libreville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=libreville
# Processing Record 146 | Kazanskaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kazanskaya
# Processing Record 147 | Tigzirt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=tigzirt
# Processing Record 148 | Fiumicino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=fiumicino
# City not found. Skipping...
# Processing Record 149 | Atocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=atocha
# Processing Record 150 | Provost
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=provost
# Processing Record 151 | Wanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=wanning
# Processing Record 152 | Gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=gizo
# Processing Record 153 | Kayerkan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kayerkan
# Processing Record 154 | Matay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=matay
# Processing Record 155 | Baie-Comeau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=baie-comeau
# Processing Record 156 | Bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=bandarbeyla
# Processing Record 157 | Sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=sur
# Processing Record 158 | Richards Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=richards%20bay
# Processing Record 159 | Schleiden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=schleiden
# Processing Record 160 | Tooele
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=tooele
# Processing Record 161 | Soyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=soyo
# Processing Record 162 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=cherskiy
# Processing Record 163 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=te%20anau
# Processing Record 164 | Kouqian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kouqian
# Processing Record 165 | Katherine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=katherine
# City not found. Skipping...
# Processing Record 166 | Kenai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kenai
# Processing Record 167 | Shuangyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=shuangyang
# Processing Record 168 | Ronne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=ronne
# Processing Record 169 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=tiksi
# Processing Record 170 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=hermanus
# Processing Record 171 | Pontianak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=pontianak
# Processing Record 172 | Verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=verkhoyansk
# Processing Record 173 | Koslan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=koslan
# Processing Record 174 | Abu Dhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=abu%20dhabi
# Processing Record 175 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=puerto%20ayora
# Processing Record 176 | Galveston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=galveston
# Processing Record 177 | Podyuga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=podyuga
# Processing Record 178 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=barrow
# City not found. Skipping...
# Processing Record 179 | Uden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=uden
# City not found. Skipping...
# Processing Record 180 | Boma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=boma
# Processing Record 181 | Paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=paamiut
# Processing Record 182 | Grand Gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=grand%20gaube
# Processing Record 183 | Kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kieta
# Processing Record 184 | Riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=riyadh
# Processing Record 185 | Bahia Blanca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=bahia%20blanca
# Processing Record 186 | Chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=chicama
# Processing Record 187 | Doka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=doka
# Processing Record 188 | Siocon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=siocon
# Processing Record 189 | Basti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=basti
# Processing Record 190 | Shanghai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=shanghai
# Processing Record 191 | Ruteng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=ruteng
# Processing Record 192 | Waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=waingapu
# Processing Record 193 | Alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=alofi
# Processing Record 194 | Jalingo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=jalingo
# Processing Record 195 | Jilib
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=jilib
# Processing Record 196 | Eyl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=eyl
# City not found. Skipping...
# Processing Record 197 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=nanortalik
# City not found. Skipping...
# Processing Record 198 | Beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=beringovskiy
# Processing Record 199 | Antsohihy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=antsohihy
# Processing Record 200 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=torbay
# Processing Record 201 | Moose Factory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=moose%20factory
# Processing Record 202 | Kautokeino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kautokeino
# Processing Record 203 | Fernan-Nunez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=fernan-nunez
# Processing Record 204 | Lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=lata
# City not found. Skipping...
# Processing Record 205 | Villa Carlos Paz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=villa%20carlos%20paz
# Processing Record 206 | Puerto Maldonado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=puerto%20maldonado
# City not found. Skipping...
# Processing Record 207 | Bintulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=bintulu
# Processing Record 208 | Volot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=volot
# Processing Record 209 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=tuktoyaktuk
# Processing Record 210 | Banda Aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=banda%20aceh
# Processing Record 211 | Calbuco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=calbuco
# Processing Record 212 | Zhangye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=zhangye
# Processing Record 213 | Tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=tautira
# City not found. Skipping...
# Processing Record 214 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kahului
# Processing Record 215 | Yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=yumen
# Processing Record 216 | High Level
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=high%20level
# Processing Record 217 | Aripuana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=aripuana
# Processing Record 218 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=ponta%20do%20sol
# Processing Record 219 | Concordia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=concordia
# Processing Record 220 | Kibala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kibala
# Processing Record 221 | Ano Mera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=ano%20mera
# Processing Record 222 | Juquitiba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=juquitiba
# City not found. Skipping...
# Processing Record 223 | Baghdad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=baghdad
# Processing Record 224 | Puerto Penasco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=puerto%20penasco
# Processing Record 225 | Oktyabrskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=oktyabrskoye
# City not found. Skipping...
# Processing Record 226 | Gweta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=gweta
# Processing Record 227 | Malkangiri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=malkangiri
# City not found. Skipping...
# Processing Record 228 | Vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=vostok
# Processing Record 229 | Aleksandrov Gay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=aleksandrov%20gay
# Processing Record 230 | Kortkeros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kortkeros
# Processing Record 231 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=upernavik
# Processing Record 232 | Troitskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=troitskoye
# Processing Record 233 | Laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=laguna
# Processing Record 234 | Tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=tura
# Processing Record 235 | Jaisalmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=jaisalmer
# Processing Record 236 | Katima Mulilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=katima%20mulilo
# Processing Record 237 | Saryozek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=saryozek
# City not found. Skipping...
# Processing Record 238 | Uvinza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=uvinza
# Processing Record 239 | Rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=rawson
# Processing Record 240 | Saint-Denis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=saint-denis
# Processing Record 241 | Conde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=conde
# Processing Record 242 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=port%20elizabeth
# Processing Record 243 | Port Moresby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=port%20moresby
# Processing Record 244 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=esperance
# Processing Record 245 | Orotukan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=orotukan
# Processing Record 246 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=ilulissat
# City not found. Skipping...
# Processing Record 247 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=sao%20filipe
# Processing Record 248 | Roald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=roald
# City not found. Skipping...
# Processing Record 249 | Centralia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=centralia
# Processing Record 250 | Kongolo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kongolo
# Processing Record 251 | Marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=marawi
# Processing Record 252 | Bushehr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=bushehr
# Processing Record 253 | Ginir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=ginir
# City not found. Skipping...
# Processing Record 254 | Hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=hirara
# Processing Record 255 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=longyearbyen
# Processing Record 256 | Mezhdurechensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=mezhdurechensk
# Processing Record 257 | Weinan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=weinan
# Processing Record 258 | Nizhniy Kuranakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=nizhniy%20kuranakh
# Processing Record 259 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=vila%20velha
# Processing Record 260 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=khatanga
# Processing Record 261 | Heishan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=heishan
# Processing Record 262 | Panalingaan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=panalingaan
# City not found. Skipping...
# Processing Record 263 | Muli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=muli
# Processing Record 264 | Dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=dingle
# Processing Record 265 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=narsaq
# City not found. Skipping...
# Processing Record 266 | Zyryanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=zyryanka
# Processing Record 267 | Cabedelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=cabedelo
# Processing Record 268 | Les Cayes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=les%20cayes
# Processing Record 269 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=sitka
# Processing Record 270 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=hasaki
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 271 | Husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=husavik
# Processing Record 272 | Las Palmas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=las%20palmas
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 273 | Auki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=auki
# Processing Record 274 | Hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=hami
# Processing Record 275 | Qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=qasigiannguit
# Processing Record 276 | Pervomayskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=pervomayskoye
# Processing Record 277 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=tuatapere
# City not found. Skipping...
# Processing Record 278 | Aden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=aden
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 279 | Maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=maragogi
# Processing Record 280 | Buraydah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=buraydah
# Processing Record 281 | Acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=acapulco
# Processing Record 282 | Marienburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=marienburg
# Processing Record 283 | Palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=palmer
# Processing Record 284 | Sergeyevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=sergeyevka
# City not found. Skipping...
# Processing Record 285 | Raton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=raton
# Processing Record 286 | Srandakan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=srandakan
# Processing Record 287 | Sarangani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=sarangani
# Processing Record 288 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=lompoc
# Processing Record 289 | Yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=yulara
# Processing Record 290 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=san%20patricio
# Processing Record 291 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=bathsheba
# Processing Record 292 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=caravelas
# Processing Record 293 | Bonfim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=bonfim
# Processing Record 294 | Khasan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=khasan
# City not found. Skipping...
# Processing Record 295 | Clarksburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=clarksburg
# Processing Record 296 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=east%20london
# Processing Record 297 | Ayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=ayan
# Processing Record 298 | Price
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=price
# Processing Record 299 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=saint%20george
# Processing Record 300 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kavaratti
# Processing Record 301 | Bonnyville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=bonnyville
# Processing Record 302 | Yongzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=yongzhou
# Processing Record 303 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=codrington
# Processing Record 304 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kaitangata
# Processing Record 305 | Skibbereen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=skibbereen
# Processing Record 306 | Kaman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kaman
# Processing Record 307 | Marsa Matruh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=marsa%20matruh
# Processing Record 308 | Perth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=perth
# Processing Record 309 | Konevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=konevo
# Processing Record 310 | Phalaborwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=phalaborwa
# Processing Record 311 | Kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kalmunai
# Processing Record 312 | Huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=huarmey
# Processing Record 313 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=pevek
# Processing Record 314 | La Orilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=la%20orilla
# Processing Record 315 | Natchitoches
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=natchitoches
# Processing Record 316 | Ust-Tsilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=ust-tsilma
# Processing Record 317 | Sajanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=sajanan
# Processing Record 318 | Pallasovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=pallasovka
# Processing Record 319 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=dunedin
# Processing Record 320 | Kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kangaatsiaq
# Processing Record 321 | Copiapo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=copiapo
# Processing Record 322 | Bull Savanna
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=rabo%20de%20peixe
# Processing Record 473 | Saurimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=saurimo
# Processing Record 474 | Cayeli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=cayeli
# Processing Record 475 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=pangnirtung
# Processing Record 476 | Mao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=mao
# Processing Record 477 | Potiskum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=potiskum
# Processing Record 478 | Hit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=hit
# Processing Record 479 | Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=barra
# City not found. Skipping...
# Processing Record 480 | Agadez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=agadez
# Processing Record 481 | Quatre Cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=quatre%20cocos
# Processing Record 482 | Lethem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=lethem
# Processing Record 483 | Ellisras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=ellisras
# Processing Record 484 | Oussouye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=oussouye
# Processing Record 485 | Raychikhinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=raychikhinsk
# Processing Record 486 | Churapcha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=churapcha
# City not found. Skipping...
# Processing Record 487 | Lensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=lensk
# Processing Record 488 | Itabirito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=itabirito
# Processing Record 489 | Taganak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=taganak
# Processing Record 490 | Manavgat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=manavgat
# Processing Record 491 | San Luis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=san%20luis
# City not found. Skipping...
# Processing Record 492 | Verkhnevilyuysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=verkhnevilyuysk
# Processing Record 493 | Guanica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=guanica
# Processing Record 494 | Severodvinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=severodvinsk
# Processing Record 495 | Nichinan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=nichinan
# Processing Record 496 | Yarada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=yarada
# Processing Record 497 | Kenora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kenora
# Processing Record 498 | Shetpe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=shetpe
# Processing Record 499 | Tarko-Sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=tarko-sale
# Processing Record 500 | Dickinson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=dickinson
# Processing Record 501 | Joshimath
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=joshimath
# Processing Record 502 | Pijijiapan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=pijijiapan
# Processing Record 503 | Port-Cartier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=port-cartier
# Processing Record 504 | Broken Hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=broken%20hill
# Processing Record 505 | Letchworth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=letchworth
# Processing Record 506 | Kualakapuas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kualakapuas
# Processing Record 507 | Solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=solnechnyy
# Processing Record 508 | Sainte-Rose
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=sainte-rose
# Processing Record 509 | Waipawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=waipawa
# Processing Record 510 | Kota Tinggi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kota%20tinggi
# Processing Record 511 | Aksu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=aksu
# Processing Record 512 | Havre-Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=havre-saint-pierre
# Processing Record 513 | Vestmanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=vestmanna
# Processing Record 514 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=fairbanks
# Processing Record 515 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=iqaluit
# Processing Record 516 | Petropavlovsk-Kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=petropavlovsk-kamchatskiy
# Processing Record 517 | Limulunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=limulunga
# Processing Record 518 | Naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=naze
# Processing Record 519 | Dire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=dire
# Processing Record 520 | Tanabe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=tanabe
# Processing Record 521 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=grindavik
# Processing Record 522 | Ahuimanu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=ahuimanu
# Processing Record 523 | Rio Gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=rio%20gallegos
# Processing Record 524 | Moses Lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=moses%20lake
# Processing Record 525 | Almaznyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=almaznyy
# Processing Record 526 | Soltvadkert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=soltvadkert
# Processing Record 527 | Vangaindrano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=vangaindrano
# City not found. Skipping...
# Processing Record 528 | Asbury Park
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=asbury%20park
# City not found. Skipping...
# Processing Record 529 | Harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=harper
# Processing Record 530 | Wamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=wamba
# Processing Record 531 | Beisfjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=beisfjord
# Processing Record 532 | Roebourne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=roebourne
# Processing Record 533 | Ouallam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=ouallam
# Processing Record 534 | Tocopilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=tocopilla
# Processing Record 535 | Mbanza-Ngungu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=mbanza-ngungu
# Processing Record 536 | Kolyubakino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kolyubakino
# Processing Record 537 | Visby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=visby
# Processing Record 538 | Juegang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=juegang
# Processing Record 539 | Ciudad Bolivar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=ciudad%20bolivar
# Processing Record 540 | Clarence Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=clarence%20town
# Processing Record 541 | Zhezkazgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=zhezkazgan
# Processing Record 542 | Coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=coihaique
# Processing Record 543 | Tupik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=tupik
# Processing Record 544 | Manta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=manta
# Processing Record 545 | Carrickfergus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=carrickfergus
# Processing Record 546 | Jumla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=jumla
# Processing Record 547 | Tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=tual
# Processing Record 548 | Arivonimamo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=arivonimamo
# Processing Record 549 | Le Port
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=le%20port
# Processing Record 550 | Treinta y Tres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=treinta%20y%20tres
# Processing Record 551 | Hayesville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=hayesville
# Processing Record 552 | Chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=chapais
# Processing Record 553 | Mercedes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=mercedes
# Processing Record 554 | Kungurtug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kungurtug
# City not found. Skipping...
# Processing Record 555 | Weston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=weston
# Processing Record 556 | Mponela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=mponela
# City not found. Skipping...
# Processing Record 557 | Doha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=doha
# City not found. Skipping...
# Processing Record 558 | Manakara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=manakara
# Processing Record 559 | Biscarrosse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=biscarrosse
# Processing Record 560 | Flin Flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=flin%20flon
# Processing Record 561 | Iquitos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=iquitos
# City not found. Skipping...
# Processing Record 562 | Trairi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=trairi
# Processing Record 563 | Elat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=elat
# Processing Record 564 | Nova Vicosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=nova%20vicosa
# Processing Record 565 | Yagodnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=yagodnoye
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 566 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=hamilton
# Processing Record 567 | Alegrete
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=alegrete
# Processing Record 568 | Sungaipenuh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=sungaipenuh
# Processing Record 569 | Morgantown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=morgantown
# Processing Record 570 | Luang Prabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=luang%20prabang
# Processing Record 571 | Bria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=bria
# Processing Record 572 | Namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=namibe
# Processing Record 573 | Kasamwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=kasamwa
# Processing Record 574 | Shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=shingu
# Processing Record 575 | Blagoyevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=blagoyevo
# Processing Record 576 | Gambela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=gambela
# Processing Record 577 | Santiago del Estero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=santiago%20del%20estero
# Processing Record 578 | Yatou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a1bd1f771debb1f97286e854b5d0b6eb&q=yatou

# %%
weather_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed}
    
weather_df = pd.DataFrame(weather_dict)

# %%
# Build a scatter plot for each data type
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)



# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)


# Show plot
plt.show()
